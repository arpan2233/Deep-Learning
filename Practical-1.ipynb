# %% [markdown]
# <a href="https://colab.research.google.com/github/arpan2233/Deep-Learning/blob/main/Practical-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory

# %%
# !kaggle datasets download -d uciml/iris
# Out:
# Dataset URL: https://www.kaggle.com/datasets/uciml/iris
# License(s): CC0-1.0
# Downloading iris.zip to /content
#   0% 0.00/3.60k [00:00<?, ?B/s]
# 100% 3.60k/3.60k [00:00<00:00, 10.1MB/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import zipfile
zip_ref=zipfile.ZipFile('iris.zip')
zip_ref.extractall('/content')
zip_ref.close()

# %%
file_path='Iris.csv'
df=pd.read_csv(file_path)

# %%
#dropping unnecessary colums
# print(df)
df_numeric = df.drop(columns=['Id', 'Species'])

# %%
#1. Mean,Median Mode
mean_value=df_numeric.mean()
print('Mean: \n',mean_value)
# Out:
# Mean:
#  SepalLengthCm    5.843333
# SepalWidthCm     3.054000
# PetalLengthCm    3.758667
# PetalWidthCm     1.198667
# dtype: float64

# %%
median_value=df_numeric.median()
print('Median: \n',median_value)
# Out:
# Median:
#  SepalLengthCm    5.80
# SepalWidthCm     3.00
# PetalLengthCm    4.35
# PetalWidthCm     1.30
# dtype: float64

# %%
mode_value=df_numeric.mode().iloc[0]
print('Mode: \n',mode_value)
# Out:
# Mode:
#  SepalLengthCm    5.0
# SepalWidthCm     3.0
# PetalLengthCm    1.5
# PetalWidthCm     0.2
# Name: 0, dtype: float64

# %%
# Percentile
percentiles = {
" 25th Percentile": df_numeric.quantile(0.25),
"50th Percentile": df_numeric.quantile(0.50),
"75th Percentile": df_numeric.quantile(0.75)
}

# %%
print(percentiles)
# Out:
# {' 25th Percentile': SepalLengthCm    5.1
# SepalWidthCm     2.8
# PetalLengthCm    1.6
# PetalWidthCm     0.3
# Name: 0.25, dtype: float64, '50th Percentile': SepalLengthCm    5.80
# SepalWidthCm     3.00
# PetalLengthCm    4.35
# PetalWidthCm     1.30
# Name: 0.5, dtype: float64, '75th Percentile': SepalLengthCm    6.4
# SepalWidthCm     3.3
# PetalLengthCm    5.1
# PetalWidthCm     1.8
# Name: 0.75, dtype: float64}

# %%
# 3. Range
range_values = df_numeric.max() - df_numeric.min()
print("Range:\n", range_values)
# Out:
# Range:
#  SepalLengthCm    3.6
# SepalWidthCm     2.4
# PetalLengthCm    5.9
# PetalWidthCm     2.4
# dtype: float64

# %%
# 4. Variance
variance_values = df_numeric.var()
print("\nVariance:\n", variance_values)
# Out:
# Variance:
#  SepalLengthCm    0.685694
# SepalWidthCm     0.188004
# PetalLengthCm    3.113179
# PetalWidthCm     0.582414
# dtype: float64

# %%
# 5. Standard Deviation
std_dev_values = df_numeric.std()
print("\nStandard Deviation:\n", std_dev_values)
# Out:
# Standard Deviation:
#  SepalLengthCm    0.828066
# SepalWidthCm     0.433594
# PetalLengthCm    1.764420
# PetalWidthCm     0.763161
# dtype: float64

# %%
# 6. Correlation Matrix
correlation_matrix = df_numeric.corr()
print("\nCorrelation Matrix:\n", correlation_matrix)
# Out:
# Correlation Matrix:
#                 SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
# 7. Covariance Matrix
covariance_matrix = df_numeric.cov()
print("\nCovariance Matrix:\n", covariance_matrix)
# Out:
# Covariance Matrix:
#                 SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       0.685694     -0.039268       1.273682      0.516904
# SepalWidthCm       -0.039268      0.188004      -0.321713     -0.117981
# PetalLengthCm       1.273682     -0.321713       3.113179      1.296387
# PetalWidthCm        0.516904     -0.117981       1.296387      0.582414

# %%
def plot_matrix(matrix, title):
    plt.figure(figsize=(6, 5))
    sns.heatmap(matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
    plt.title(title)
    plt.show()

# Plot covariance and correlation matrices
plot_matrix(covariance_matrix, "Covariance Matrix")

# %%
# Plot covariance and correlation matrices
plot_matrix(correlation_matrix, "Correlation Matrix")
